# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.pre_tokenizers import ByteLevel
from tokenizers.trainers import BpeTrainer
from tokenizers.decoders import ByteLevel as ByteLevelDecoder
from pathlib import Path

# %%
FOLDER_PATH = Path.cwd() / "models" 
FILE_PATH = FOLDER_PATH / "tokenizer.json"
DATA_FILE = Path.cwd() / "data" / "data.txt"

# %%
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))

# Set the pre-tokenizer to ByteLevel
tokenizer.pre_tokenizer = ByteLevel()
tokenizer.decoder = ByteLevelDecoder()

# Configure the trainer
trainer = BpeTrainer(vocab_size=30000,  min_frequency=2, special_tokens=["[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]"])

# Train the tokenizer on your text file
files = [str(DATA_FILE)]
print("Training the tokenizer... This might take a moment.")
tokenizer.train(files, trainer)
print("Training complete!")

FOLDER_PATH.mkdir(parents=True, exist_ok=True)

# 5. Save the tokenizer for future use
tokenizer.save(str(FILE_PATH))
# Out:
# Training the tokenizer... This might take a moment.
# Training complete!

# %%
tokenizer = Tokenizer.from_file(str(FILE_PATH))

text = "All the way till the end of the world, we will be together. No matter what happens, I will always be there for you."
enc = tokenizer.encode(text)

print("Tokens:")
print(enc.tokens)

print("\nIDs:")
print(enc.ids)

decoded = tokenizer.decode(enc.ids)

print("\nDecoded:")
print(decoded)
# Out:
# Tokens:
# ['ĠAll', 'Ġthe', 'Ġway', 'Ġtill', 'Ġthe', 'Ġend', 'Ġof', 'Ġthe', 'Ġworld', ',', 'Ġwe', 'Ġwill', 'Ġbe', 'Ġtogether', '.', 'ĠNo', 'Ġmatter', 'Ġwhat', 'Ġhappens', ',', 'ĠI', 'Ġwill', 'Ġalways', 'Ġbe', 'Ġthere', 'Ġfor', 'Ġyou', '.']
#
# IDs:
# [1764, 94, 488, 6607, 94, 663, 114, 94, 1978, 14, 171, 315, 136, 1174, 16, 1845, 461, 300, 7443, 14, 110, 315, 825, 136, 270, 182, 137, 16]
#
# Decoded:
#  All the way till the end of the world, we will be together. No matter what happens, I will always be there for you.
